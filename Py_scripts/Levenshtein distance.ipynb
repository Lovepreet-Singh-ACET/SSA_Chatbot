# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install fuzzywuzzy

# %%
import pandas as pd
from fuzzywuzzy import fuzz
# Out:
# /usr/local/lib/python3.7/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# !ls "/content/drive/Shareddrives/SSA chatbot/SSA_Chatbot/Lovepreet/unique"
# Out:
#  wheat_unique_17.csv
# 'wheat_unique_agriculture mechanization.csv'
# 'wheat_unique_biopesticides and biofertilizers.csv'
# 'wheat_unique_crop insurance.csv'
# 'wheat_unique_cultural practices.csv'
# 'wheat_unique_fertilizer use and availability.csv'
# 'wheat_unique_fertilizer used.csv'
# 'wheat_unique_field preparation.csv'
# 'wheat_unique_government schemes.csv'
# 'wheat_unique_improved variety of crop.csv'
# 'wheat_unique_market information.csv'
# 'wheat_unique_nutrient management.csv'
# 'wheat_unique_nutrient management.gsheet'
# 'wheat_unique_plant protection.csv'
# 'wheat_unique_post harvest preservation.csv'
# 'wheat_unique_power roads etc.csv'
#  wheat_unique_seeds.csv
# 'wheat_unique_seed treatment.csv'
# 'wheat_unique_soil testing.csv'
#  wheat_unique_Sowing-Harvesting_Time.csv
# 'wheat_unique_sowing time and weather.csv'
#  wheat_unique_storage.csv
# 'wheat_unique_training and exposure visits.csv'
#  wheat_unique_varieties.csv
# 'wheat_unique_water management.csv'
# ...

# %%
file_names = [
    # 'wheat_unique_17.csv',
    'wheat_unique_agriculture mechanization.csv',
    'wheat_unique_biopesticides and biofertilizers.csv',
    'wheat_unique_crop insurance.csv',
    'wheat_unique_cultural practices.csv',
    'wheat_unique_field preparation.csv',
    'wheat_unique_government schemes.csv',
    'wheat_unique_improved variety of crop.csv',
    'wheat_unique_market information.csv',
    'wheat_unique_nutrient management.csv',
    'wheat_unique_post harvest preservation.csv',
    'wheat_unique_power roads etc.csv',
    'wheat_unique_seeds.csv',
    'wheat_unique_soil testing.csv',
    'wheat_unique_sowing time and weather.csv',
    'wheat_unique_storage.csv',
    'wheat_unique_training and exposure visits.csv',
    'wheat_unique_varieties.csv',
    'wheat_unique_water management.csv'
    ]

# %%
to_save_path = "/content/drive/Shareddrives/SSA chatbot/SSA_Chatbot/Lovepreet/unique_after_script/"
path = "/content/drive/Shareddrives/SSA chatbot/SSA_Chatbot/Lovepreet/unique/"
question_set = pd.read_csv("/content/drive/Shareddrives/SSA chatbot/SSA_Chatbot/Added_Questions_Set.csv")
# print(question_set.columns)
# questoions

for filename in file_names:
  # print(path + filename)
  # print("\n\n")
  # print(filename)
  # print("---------------------------------------------------------------")
  data = []
  df = pd.read_csv(path+filename)
  for qt in df['ques']:
    flag = 0
    for q in question_set['questoions']:
      if fuzz.token_set_ratio(qt, q) > 85:
        flag = 1
        break
    if flag == 0:
      data.append(qt)
    
    df = pd.DataFrame({"Ques": data})
    df.to_csv(to_save_path + "scripted_" +filename, index=False)
  # print(df.columns)
  # fuzz.token_set_ratio()

# %%
# to_save_path = "/content/drive/Shareddrives/SSA chatbot/SSA_Chatbot/Lovepreet/unique_after_script/"
path = "/content/drive/Shareddrives/SSA chatbot/SSA_Chatbot/Lovepreet/unique/"
question_set = pd.read_csv("/content/drive/Shareddrives/SSA chatbot/SSA_Chatbot/Added_Questions_Set.csv")
# print(question_set.columns)
# questoions
file_name = []
len_data = []
for filename in file_names:
  # print(path + filename)
  # print("\n\n")
  # print(filename)
  # print("---------------------------------------------------------------")
  data = []
  df = pd.read_csv(path+filename)
  for qt in df['ques']:
    flag = 0
    for q in question_set['questoions']:
      if fuzz.token_set_ratio(qt, q) > 85:
        flag = 1
        break
    if flag == 0:
      data.append(qt)
    
    file_name.append(filename)
    len_data.append(len(data))
    # df = pd.DataFrame({"Ques": data})
    # df.to_csv(to_save_path + "scripted_" +filename, index=False)
  # print(df.columns)
  # fuzz.token_set_ratio()

df2 = pd.DataFrame({"filename": file_name, "len_unique": len_data})
df2.to_csv("/content/drive/Shareddrives/SSA chatbot/SSA_Chatbot/Lovepreet/len_unique_after_fuzzy.csv")
